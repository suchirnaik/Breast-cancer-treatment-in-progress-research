# %%
def perform_diagnosis():
    print("Choose one of the following options:")
    print("1. DCIS Tis, N0, M0 diagnosed")
    print("2. Non-metastatic (M0) invasive breast cancer")
    print("3. Metastatic (M1) invasive breast cancer and Stage IV (M1) or Recurrent disease")
    print("4. Clinical pathologic diagnosis of inflammatory breast cancer")
    
    option = input("Enter the option number: ")
    
    if option == "1":
        # DCIS Tis, N0, M0 diagnosed
        dcis_treatment = input("Is the treatment plan Breast conserving surgery or total mastectomy? (Breast conserving surgery/total mastectomy): ").strip().lower()
        
        if dcis_treatment == "breast conserving surgery":
            print("For DCIS treatment:\n"
                  "- History and physical exam\n"
                  "- Diagnostic bilateral mammogram\n"
                  "- Pathology review\n"
                  "- Determination of tumor estrogen receptor (ER) status\n"
                  "- Genetic counseling for patients at risk of hereditary breast cancer\n"
                  "- Breast MRI as indicated\n"
                  "And for Breast conserving surgery:\n"
                  "- Whole breast radiation therapy (WBRT) (category 1) with or without boost to tumor bed or\n"
                  "- Accelerated partial breast irradiation/partial breast radiation (APBI/PBI) or\n"
                  "- No RT (category 2B)\n"
                  "And for Risk reduction therapy for ipsilateral breast following BCS:\n"
                  "- Consider endocrine therapy for 5 years for patients with ER-positive DCIS, if:\n"
                  "  - Treated with BCS and RTm (category 1)\n"
                  "  - Treated with excision alone\n"
                  "- Endocrine therapy:\n"
                  "  - Tamoxifenm,o for premenopausal patients\n"
                  "  - Tamoxifenm,o or aromatase inhibitor for postmenopausal patients with some advantage for aromatase inhibitor therapy in patients <60 years or with concerns for thromboembolism\n"
                  "And for Risk reduction therapy for contralateral breast:\n"
                  "- Counseling regarding risk reduction\n"
                  "And Surveillance and Follow Up:\n"
                  "- Interval history and physical exam every 6–12 mo for 5 y, then annually\n"
                  "- Mammogram every 12 mo (first mammogram 6–12 mo, after breast-conservation therapy, category 2B)")

        elif dcis_treatment == "total mastectomy":
            print("For DCIS treatment:\n"
                  "- History and physical exam\n"
                  "- Diagnostic bilateral mammogram\n"
                  "- Pathology review\n"
                  "- Determination of tumor estrogen receptor (ER) status\n"
                  "- Genetic counseling for patients at risk of hereditary breast cancer\n"
                  "- Breast MRI as indicated\n"
                  "And for Total mastectomy:\n"
                  "See the following post-surgical treatment:\n"
                  "- Risk reduction therapy for contralateral breast:\n"
                  "  - Counseling regarding risk reduction\n"
                  "And Surveillance and Follow Up:\n"
                  "- Interval history and physical exam every 6–12 mo for 5 y, then annually\n"
                  "- Mammogram every 12 mo (first mammogram 6–12 mo, after breast-conservation therapy, category 2B)")

        else:
            print("Invalid choice for treatment. Please choose 'Breast conserving surgery' or 'total mastectomy'.")

    elif option == "2":
        # Non-metastatic (M0) invasive breast cancer
        print("Due to non Non-metastatic (M0) invasive breast cancer:")
        cT0_cNplus_M0 = input("Is cT0, cN+ and M0 from imaging and testing? (Yes/No): ").strip().lower()
        
        if cT0_cNplus_M0 == "yes":
            print("See NCCN guidelines for Occult Primary")
        else:
            cT1_T3_cN0_M0 = input("Is cT1–T3 and ≥cN0,M0 from imaging and testing? (Yes/No): ").strip().lower()
            if cT1_T3_cN0_M0 == "yes":
                print("See criteria for preoperative systemic therapy (BINV-M)")
                considering_preop_sys_therapy = input("Are you considering preoperative systemic therapy? (Yes/No): ").strip().lower()
                if considering_preop_sys_therapy == "no":
                    print("Locoregional treatment:")
                    print("- See BCS Followed by RT (BINV-2) or")  # Reference to BINV-2
                    print("- See Mastectomy Followed by RT (BINV-3)")
                    ask_for_BINV2_rules()
                    ask_for_BINV3_rules()
                elif considering_preop_sys_therapy == "yes":
                    print("See Additional Workup Prior to Preoperative Systemic Therapy (BINV-12)")
                    ask_for_BINV12_rule()
            else:
                print("Invalid choice for cT1–T3, ≥cN0,M0. Please choose 'yes' or 'no'.")

    elif option == "3":
        # Metastatic (M1) invasive breast cancer and Stage IV (M1) or Recurrent disease
        print("Due to Metastatic (M1) invasive breast cancer and Stage IV (M1) or Recurrent disease:")
        print("See Workup for Recurrent or Stage IV (M1) Disease (BINV-18)")

    elif option == "4":
        # Clinical pathologic diagnosis of inflammatory breast cancer (IBC)
        print("Due to Clinical pathologic diagnosis of inflammatory breast cancer (IBC):")
        print("See Workup for IBC (IBC-1)")

    else:
        print("Invalid choice. Please choose a valid option (1, 2, 3, or 4).")

# Function to ask if the user wants to see BINV2 rules
def ask_for_BINV2_rules():
    user_response = input("Do you want to know the BINV2 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV2 rules:")
        print("Rule 1: Is it BCS with surgical axillary staging (category 1)i,j,k,l ± oncoplastic reconstruction and if Negative axillary nodes?")
        user_response = input(" (Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Then WBRT ± boost to the tumor bed, and consider comprehensive regional nodal irradiation (RNI) in patients with central/medial tumors, pT3 tumors, or pT2 tumors and one of the following high-risk features: grade 3, extensive lymphovascular invasion (LVI), or ER-negative. Or consider APBI/PBI in selected low-risk patients (category 1) or consider omitting breast irradiation in patients ≥70 y of age with ER-positive, cN0, pT1 tumors who receive adjuvant endocrine therapy (category 1) and see BINV 4.")
        elif user_response == "no":
            print("Rule 2: Is it BCS with surgical axillary staging (category 1) ± oncoplastic reconstruction and if 1–3 positive axillary nodes and meets ALL of the following criteria: • cT1–T2, cN0 • No preoperative chemotherapy • 1–2 positive sentinel lymph node (SLNs) • WBRT planned")
            user_response = input(" (Yes/No): ").strip().lower()
            if user_response == "yes":
                print("Then WBRT ± boost (use of comprehensive RNI with or without intentional inclusion of axilla is at the discretion of the radiation oncologist) (category 1) and see BINV4.")
            elif user_response == "no":
                print("Rule 3: Is it BCS with surgical axillary staging (category 1) ± oncoplastic reconstruction and if 1–3 positive axillary nodes and does not meet ALL of the following criteria: • cT1–T2, cN0 • No preoperative chemotherapy • 1–2 positive sentinel lymph node (SLNs) • WBRT planned")
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == "yes":
                    print("Then WBRT with the inclusion of any portion of the undissected axilla at risk ± boost to the tumor bed (category 1). Strongly consider comprehensive RNI and see BINV4.")
                elif user_response == "no":
                    print("Rule 4: Is it BCS with surgical axillary staging (category 1)i,j,k,l ± oncoplastic reconstruction and if ≥4 positive axillary nodes?")
                    user_response = input("(Yes/No): ").strip().lower()
                    if user_response == 'yes':
                        print("Then WBRT ± boost to the tumor bed (category 1) + comprehensive RNI with the inclusion of any portion of the undissected axilla at risk (category 1) and see BINV4.")
                    elif user_response == 'no':
                        print("No BINV2 rules will be provided.")
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")

            
# Function to ask if the user wants to see BINV# rules
def ask_for_BINV3_rules():
    user_response = input("Do you want to know the BINV3 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV3 rules:")
        print("Rule 21: Is patient undergoing total mastectomy with surgical axillary staging i,j,k (category 1) ± reconstruction, And IF negative axillary nodes and tumor ≤5 cm and margins ≥1 mm")
        user_response = input(" (Yes/No): ").strip().lower()
        if user_response == "yes":
            print("No radiation therapy (RT) needed. See BINV4")
            ask_for_BINV4_rules()
        elif user_response == "no":
            print("Rule 22: Is patient undergoing total mastectomy with surgical axillary staging i,j,k (category 1) ± reconstruction, And IF negative axillary nodes and tumor ≤5 cm and negative margins")
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == 'yes':
                print("Consider RT to chest wall. For patients with additional high-risk features, consider addition of comprehensive regional nodal irradiation (RNI) (including any portion of the undissected axilla at risk). See BINV4")
                ask_for_BINV4_rules()
            elif user_response == "no": 
                print("Rule 23: Is patient undergoing total mastectomy with surgical axillary staging i,j,k (category 1) ± reconstruction, And IF negative axillary nodes and tumor >5 cm")
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == 'yes':
                    print("Consider RT to chest wall ± comprehensive RNI (including any portion of the undissected axilla at risk. See BIN4")
                    ask_for_BINV4_rules()
                elif user_response == "no":
                    print("Rule 24: Is patient undergoing total mastectomy with surgical axillary staging i,j,k (category 1) ± reconstruction, and IF 1–3 positive axillary nodes")
                    user_response = input("(Yes/No): ").strip().lower()
                    if user_response == 'yes':
                        print("Strongly consider RT to chest wall + comprehensive RNI (including any portion of the undissected axilla at risk. See BINV4")
                        ask_for_BINV4_rules()
                    elif user_response == "no":
                        print("Rule 25: Is patient undergoing total mastectomy with surgical axillary staging i,j,k (category 1) ± reconstruction, and IF ≥4 positive axillary nodes")
                        user_response = input("(Yes/No): ").strip().lower()
                        if user_response == 'yes':
                            print("THEN RT to chest wall + comprehensive RNI (including any portion of the undissected axilla at risk) is recommended (category 1). See BINV4")
                            ask_for_BINV4_rules()
                        elif user_response == "no":
                            print("Rule 26: Is patient undergoing total mastectomy with surgical axillary staging i,j,k (category 1) ± reconstruction, and IF margins are positive")
                            user_response = input("(Yes/No): ").strip().lower()
                            if user_response == 'yes':
                                print("Re-excision to achieve negative margins is preferred. If not feasible, strongly consider RT to chest wall ± comprehensive RNI (including any portion of the undissected axilla at risk. See BINV4")
                                ask_for_BINV4_rules()
                            elif user_response == 'no':
                                print("No BINV2 rules will be provided.")
                            else:
                                print("Invalid response. Please answer 'Yes' or 'No'.")
                        else:
                            print("Invalid response. Please answer 'Yes' or 'No'.")
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")

                            
                        
def ask_for_BINV4_rules():
    user_response = input("Do you want to know the BINV4 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV4 rules:")
        print("Rule 27: Is tumor is of histologic type:\n"
              "- Ductal/NST\n"
              "- Lobular\n"
              "- Mixed\n"
              "- Micropapillary\n"
              "- Metaplastic\n"
              "AND\n"
              "ER-positive and/or PR-positive\n"
              "AND\n"
              "HER2-positive?\n")
        user_response = input(" (Yes/No): ").strip().lower()
        if user_response == "yes":
            print("See BINV-5")
            ask_for_BINV5_rules() 
        elif user_response == "no":
            print("Rule 28: IF tumor is of histologic type:\n"
                  "- Ductal/NST\n"
                  "- Lobular\n"
                  "- Mixed\n"
                  "- Micropapillary\n"
                  "- Metaplastic\n"
                  "AND\n"
                  "ER-positive and/or PR-positive\n"
                  "AND\n"
                  "HER2-negative\n"
                  "AND\n"
                  "Postmenopausal,")
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == 'yes':
                print("See BINV-6")
                ask_for_BINV6_rules()
            elif user_response == "no":
                print("Rule 29: IF tumor is of histologic type:\n"
                      "- Ductal/NST\n"
                      "- Lobular\n"
                      "- Mixed\n"
                      "- Micropapillary\n"
                      "- Metaplastic\n"
                      "AND\n"
                      "ER-positive and/or PR-positive\n"
                      "AND\n"
                      "HER2-negative\n"
                      "AND\n"
                      "Premenopausal\n"
                      "AND\n"
                      "pT1–3 AND pN0,")
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == 'yes':
                    print("See BINV-7")
                    ask_for_BINV7_rules()
                elif user_response == "no":
                    print("Rule 30: IF tumor is of histologic type:\n"
                          "- Ductal/NST\n"
                          "- Lobular\n"
                          "- Mixed\n"
                          "- Micropapillary\n"
                          "- Metaplastic\n"
                          "AND\n"
                          "ER-positive and/or PR-positive\n"
                          "AND\n"
                          "HER2-negative\n"
                          "AND\n"
                          "Premenopausal\n"
                          "AND\n"
                          "pT1–3 AND pN+,")
                          
                    user_response = input("(Yes/No): ").strip().lower()
                    if user_response == 'yes':
                        print("See BINV-8")
                        ask_for_BINV8_rules()
                    elif user_response == "no":
                        print("Rule 31: IF tumor is of histologic type:\n"
                              "- Ductal/NST\n"
                              "- Lobular\n"
                              "- Mixed\n"
                              "- Micropapillary\n"
                              "- Metaplastic\n"
                              "AND\n"
                              "ER-negative and PR-negative\n"
                              "AND\n"
                              "HER2-positive,")
                              
                        user_response = input("(Yes/No): ").strip().lower()
                        if user_response == 'yes':
                            print("See BINV-9")
                            ask_for_BINV9_rules()
                        elif user_response == "no":
                            print("Rule 32: IF tumor is of histologic type:\n"
                                  "- Ductal/NST\n"
                                  "- Lobular\n"
                                  "- Mixed\n"
                                  "- Micropapillary\n"
                                  "- Metaplastic\n"
                                  "AND\n"
                                  "ER-negative and PR-negative\n"
                                  "AND\n"
                                  "HER2-negative,")
                                  
                            user_response = input("(Yes/No): ").strip().lower()
                            if user_response == 'yes':
                                print("See BINV-10")
                                ask_for_BINV10_rules()
                            elif user_response == 'no':
                                print("Rule 33: IF tumor is of histologic type:\n"
                                      "- Favorable histologic type:\n"
                                      "  - Pure tubular\n"
                                      "  - Pure mucinous\n"
                                      "  - Pure cribriform\n"
                                      "  - Encapsulated or solid papillary carcinoma (SPC)\n"
                                      "  - Adenoid cystic and other salivary carcinomas\n"
                                      "  - Secretory carcinoma\n"
                                      "  - Rare low-grade forms of metaplastic carcinoma\n"
                                      "AND\n"
                                      "ER-positive and/or PR-positive OR ER-negative and PR-negative,")
                                      
                                user_response = input("(Yes/No): ").strip().lower()
                                if user_response == 'yes':
                                    print("See Favourable Histologies (BINV-11)")
                                    ask_for_BINV11_rules()
                                elif user_response == 'no':
                                    print("No BINV4 rules will be provided.")
                                else:
                                    print("Invalid response. Please answer 'Yes' or 'No'.")
                            else:
                                print("Invalid response. Please answer 'Yes' or 'No'.")
                        else:
                            print("Invalid response. Please answer 'Yes' or 'No'.")
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
                       
def ask_for_BINV5_rules():
    user_response = input("Do you want to know the BINV5 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV5 rules:")
        print("Rule 34: IF tumor is of histologic type:\n"
              "- Ductal/NST\n"
              "- Lobular\n"
              "- Mixed\n"
              "- Micropapillary\n"
              "AND\n"
              "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
              "AND\n"
              "- Tumor ≤0.5 cm\n"
              "AND\n"
              "- pN0\n")
              

        user_response = input(" (Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Consider adjuvant endocrine therapy ± adjuvant chemotherapya,bb,cc with trastuzumabdd,ee (category 2B). See Follow up BINV-17")
        elif user_response == "no":
            print("Rule 35: IF tumor is of histologic type:\n"
                  "- Ductal/NST\n"
                  "- Lobular\n"
                  "- Mixed\n"
                  "- Micropapillary\n"
                  "AND\n"
                  "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                  "AND\n"
                  "- Tumor ≤0.5 cm\n"
                  "AND\n"
                  "- pN1mi\n")
                  
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == 'yes':
                print("Adjuvant endocrine therapybb,ff or Adjuvant chemotherapya,bb,cc with trastuzumabdd and endocrine therapybb,. See Follow up BINV-17")
            elif user_response == "no":
                print("Rule 36: IF tumor is of histologic type:\n"
                      "- Ductal/NST\n"
                      "- Lobular\n"
                      "- Mixed\n"
                      "- Micropapillary\n"
                      "AND\n"
                      "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                      "AND\n"
                      "- Tumor 0.6–1.0 cm\n")
                      
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == 'yes':
                    print("Adjuvant endocrine therapybb,ff or Adjuvant chemotherapya,bb,cc with trastuzumabdd and endocrine therapybb. See Follow up BINV-17")
                elif user_response == "no":
                    print("Rule 37: IF tumor is of histologic type:\n"
                          "- Ductal/NST\n"
                          "- Lobular\n"
                          "- Mixed\n"
                          "- Micropapillary\n"
                          "AND\n"
                          "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                          "AND\n"
                          "- Tumor >1 cm\n")
                          
                    user_response = input("(Yes/No): ").strip().lower()
                    if user_response == 'yes':
                        print("Adjuvant chemotherapya,bb,cc with trastuzumab (category 1) and endocrine therapybb.See Follow up BINV-17")
                    elif user_response == 'no':
                        print("Rule 38: IF tumor is of histologic type:\n"
                              "- Ductal/NST\n"
                              "- Lobular\n"
                              "- Mixed\n"
                              "- Micropapillary\n"
                              "AND\n"
                              "- pN+ (≥1 ipsilateral metastases >2 mm)\n")
                              
                            
                        user_response = input("(Yes/No): ").strip().lower()
                        if user_response == 'yes':
                            print("Adjuvant chemotherapya,bb,cc with trastuzumabdd (category 1) and endocrine therapybb,ff,gg or Adjuvant chemotherapya,bb,cc with trastuzumabdd + pertuzumabhh (category 1, preferred) and endocrine therapybb,ff,gg. See Follow up BINV-17")
                        elif user_response == 'no':
                            print("No BINV5 rules will be provided.")
                        else:
                            print("Invalid response. Please answer 'Yes' or 'No'.")
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")

            
def ask_for_BINV6_rules():
    user_response = input("Do you want to know the BINV6 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV6 rules:")
        print("Rule 39: IF tumor is of histologic type:\n"
              "- Ductal/NSTu\n"
              "- Lobular\n"
              "- Mixed\n"
              "- Micropapillary\n"
              "AND\n"
              "- Tumor ≤0.5 cm and pN0\n")
              

        user_response = input(" (Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Consider adjuvant endocrine therapy (category 2B).See BINV-17")
        elif user_response == "no":
            print("Rule 40: IF tumor is of histologic type:\n"
                  "- Ductal/NSTu\n"
                  "- Lobular\n"
                  "- Mixed\n"
                  "- Micropapillary\n"
                  "AND\n"
                  "- Tumor >0.5 cm or pN1mi (≤2 mm axillary node metastases) or pN1 (1–3 positive nodes)\n"
                  "THEN\n"
                  "Strongly consider 21-gene RTPCR assay if a candidate for chemotherapy (category 1)\n"
                  "[\n"
                  "IF 21-gene RTPCR assay not done\n"
                  "THEN\n"
                  "Adjuvant chemotherapy followed by endocrine therapy (category 1) or Adjuvant endocrine therapy\n"
                  "AND\n"
                  "See BINV-17\n\n"
                  "ELSE IF\n"
                  "21-gene RTPCR Recurrence score <26\n"
                  "THEN\n"
                  "Adjuvant endocrine therapy (category 1)\n"
                  "AND\n"
                  "See BINV-17\n\n"
                  "ELSE IF\n"
                  "21-gene RTPCR Recurrence score ≥26\n")
                  

            user_response = input(" (Yes/No): ").strip().lower()
            if user_response == 'yes':
                print("Adjuvant chemotherapy followed by endocrine therapy (category 1) or Adjuvant chemotherapy followed by endocrine therapy (category 1). See BINV-17")
            elif user_response == "no":
                print("Rule 41: IF tumor is of histologic type:\n"
                      "- Ductal/NSTu\n"
                      "- Lobular\n"
                      "- Mixed\n"
                      "- Micropapillary\n"
                      "AND\n"
                      "- pN2/pN3 (≥4 ipsilateral metastases >2 mm)\n")
                if user_response == 'yes':
                    print("Adjuvant chemotherapy followed by endocrine therapy (category 1). See BINV-17")
                elif user_response == 'no':
                    print("No BINV6 rules will be provided.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")            
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")

        
def ask_for_BINV7_rules():
    user_response = input("Do you want to know the BINV7 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV7 rules:")
        print("Rule 42: IF tumor is of histologic type:\n"
              "- Ductal/NSTu\n"
              "- Lobular\n"
              "- Mixed\n"
              "- Micropapillary\n"
              "AND\n"
              "- Tumor ≤0.5 cm and pN0\n")
             

        user_response = input(" (Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Consider adjuvant endocrine therapy (category 2B).See BINV-17")
        elif user_response == "no":
            print("Rule 43: IF tumor is of histologic type:\n"
                  "- Ductal/NSTu\n"
                  "- Lobular\n"
                  "- Mixed\n"
                  "- Micropapillary\n"
                  "AND\n"
                  "- Tumor >0.5 cm and pN0\n")
            if user_response == "yes":
                print("Strongly consider 21-gene RT-PCR assay if a candidate for chemotherapy (category 1). Refer to BINV-7a")
                ask_for_BINV7a_rules
            elif user_response == 'no':
                print("No BINV7 rules will be provided.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")          
            
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")


def ask_for_BINV7a_rules():
    user_response = input("Do you want to know the BINV7a rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV7a rules:")
        print("Rule 1: IF 21-gene RT-PCR assay Not Done\n")
              
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Adjuvant chemotherapycc followed by endocrine therapybb,ff (category 1) or Adjuvant endocrine therapybb,ff ± ovarian suppression/ablationbb,f.See BINV-17")
        elif user_response == "no":
            print("Rule 2: ELSE IF RT-PCR assay Recurrence score ≤15\n")
                  
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == "yes":
                print("Adjuvant endocrine therapybb,ff ± ovarian suppression/ablationbb. See BINV-17")
            elif user_response == "no":
                print("Rule 3: ELSE IF RT-PCR assay Recurrence score 16–25\n")
                     
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == "yes":
                    print("Adjuvant endocrine therapybb,ff ± ovarian suppression/ablationbb,ff,mm or Adjuvant chemotherapycc followed by endocrine therapybb,ff. See BINV-17")
                elif user_response == "no":
                    print("Rule 4: ELSE IF RT-PCR Recurrence score ≥26\n")
                    if user_response == "yes":
                        print("Adjuvant chemotherapycc followed by endocrine therapybb,f")
                    elif user_response == 'no':
                        print("No BINV7a rules will be provided.")
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")        
                    
                         
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")

def ask_for_BINV8_rules():
    user_response = input("Do you want to know the BINV8 Rule 44? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Rule 44: IF tumor is of histologic type:\n"
              "- Ductal/NSTu\n"
              "- Lobular\n"
              "- Mixed\n"
              "- Micropapillary\n"
              "AND\n"
              "- pN1mi (≤2 mm axillary node metastasis) or pN1 (1–3 positive nodes)\n")
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Assess to determine if candidate for chemotherapy. Refer to BINV 8a")
            ask_for_BINV8a_rules
        elif user_response == "no":
            print("No BINV8 rules will be provided.") 
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")

def ask_for_BINV8a_rules():
    user_response = input("Do you want to know the BINV8a rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV8a rules:")
        print("Rule 1: IF Not a candidate for chemotherapy\n")
             
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Adjuvant endocrine therapy + ovarian suppression/ablationb.See Binv-17")
        elif user_response == "no":
            print("Rule 2: ELSE IF candidate for chemotherapy\n"
                  "THEN\n"
                  "Consider gene expression assay to assess prognosis\n")
                
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == "yes":
                print("Adjuvant chemotherapybb,cc followed by endocrine therapybb,ff,mm or Adjuvant endocrine therapy + ovarian suppression/ablation. See Binv-17")
            elif user_response == "no":
                print("Rule 3: IF tumor is of histologic type:\n"
                      "- Ductal/NSTu\n"
                      "- Lobular\n"
                      "- Mixed\n"
                      "- Micropapillary\n"
                      "AND\n"
                      "- pN2/pN3 (≥4 ipsilateral metastases >2 mm)nn\n")
                if user_response == "yes":
                    print("Adjuvant chemotherapybb,cc followed by endocrine therapybb,ff,ll (category 1)")
                elif user_response == "no":
                    print("No BINV8a rules will be provided.") 
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")      
                     
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")

def ask_for_BINV9_rules():
    user_response = input("Do you want to know the BINV9 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV9 rules:")
        print("Rule 45: IF tumor is of histologic type:\n"
              "- Ductal/NSTu\n"
              "- Lobular\n"
              "- Mixed\n"
              "- Micropapillary\n"
              "AND\n"
              "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
              "AND\n"
              "- Tumor ≤0.5 cm\n"
              "AND\n"
              "- pN0\n")
             
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Consider adjuvant chemotherapya,pp with trastuzumabdd,ee (category 2B).See BINV 17")
        elif user_response == "no":
            print("Rule 46: IF tumor is of histologic type:\n"
                  "- Ductal/NSTu\n"
                  "- Lobular\n"
                  "- Mixed\n"
                  "- Micropapillary\n"
                  "AND\n"
                  "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                  "AND\n"
                  "- Tumor ≤0.5 cm\n"
                  "AND\n"
                  "- pN1mi\n")
                  
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == "yes":
                print("Consider adjuvant chemotherapya,pp with trastuzumabdd,e. See BINV 17")
            elif user_response == "no":
                print("Rule 47: IF tumor is of histologic type:\n"
                      "- Ductal/NSTu\n"
                      "- Lobular\n"
                      "- Mixed\n"
                      "- Micropapillary\n"
                      "AND\n"
                      "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                      "AND\n"
                      "- Tumor 0.6–1.0 cm\n")
                      
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == "yes":
                    print("Consider adjuvant chemotherapya,pp with trastuzumabd. See BINV 17")
                elif user_response == "no":
                    print("Rule 48: IF tumor is of histologic type:\n"
                          "- Ductal/NSTu\n"
                          "- Lobular\n"
                          "- Mixed\n"
                          "- Micropapillary\n"
                          "AND\n"
                          "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                          "AND\n"
                          "- Tumor >1 cm\n")
                          
                    user_response = input("(Yes/No): ").strip().lower()
                    if user_response == "yes":
                        print("Adjuvant chemotherapya,pp with trastuzumabff (category 1). See BINV 17")
                    elif user_response == "no":
                        print("Rule 49: IF tumor is of histologic type:\n"
                              "- Ductal/NSTu\n"
                              "- Lobular\n"
                              "- Mixed\n"
                              "- Micropapillary\n"
                              "AND\n"
                              "- pN+ (≥1 ipsilateral metastases >2 mm)\n")
                        if user_response == "yes":
                            print("Adjuvant chemotherapya,pp with trastuzumabff (category 1) or Adjuvant chemotherapya,pp with trastuzumabff + pertuzumab")
                        elif user_response == "no":
                            print("No BINV9 rules will be provided.")
                        else:
                            print("Invalid response. Please answer 'Yes' or 'No'.")          
                        
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")


def ask_for_BINV10_rules():
    user_response = input("Do you want to know the BINV10 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV10 rules:")
        print("Rule 50: IF tumor is of histologic type:\n"
              "- Ductal/NSTu\n"
              "- Lobular\n"
              "- Mixed\n"
              "- Micropapillary\n"
              "- Metaplasticv\n"
              "AND\n"
              "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
              "AND\n"
              "- Tumor ≤0.5 cm\n"
              "AND\n"
              "- pN0\n"
              "THEN\n"
              "No adjuvant therapyqq\n"
              "AND\n"
              "See BINV 17")
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("See BINV 17")
        elif user_response == "no":
            print("Rule 51: IF tumor is of histologic type:\n"
                  "- Ductal/NSTu\n"
                  "- Lobular\n"
                  "- Mixed\n"
                  "- Micropapillary\n"
                  "- Metaplasticv\n"
                  "AND\n"
                  "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                  "AND\n"
                  "- Tumor ≤0.5 cm\n"
                  "AND\n"
                  "- pN1mi\n"
                  "THEN\n"
                  "Consider adjuvant chemotherapya,c\n"
                  "AND\n"
                  "See BINV 17")
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == "yes":
                print("See BINV 17")
            elif user_response == "no":
                print("Rule 52: IF tumor is of histologic type:\n"
                      "- Ductal/NSTu\n"
                      "- Lobular\n"
                      "- Mixed\n"
                      "- Micropapillary\n"
                      "- Metaplasticv\n"
                      "AND\n"
                      "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                      "AND\n"
                      "- Tumor 0.6–1.0 cm\n"
                      "THEN\n"
                      "Consider adjuvant chemotherapya,cc\n"
                      "AND\n"
                      "See BINV 17")
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == "yes":
                    print("See BINV 17")
                elif user_response == "no":
                    print("Rule 53: IF tumor is of histologic type:\n"
                          "- Ductal/NSTu\n"
                          "- Lobular\n"
                          "- Mixed\n"
                          "- Micropapillary\n"
                          "- Metaplasticv\n"
                          "AND\n"
                          "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                          "AND\n"
                          "- Tumor >1 cm\n"
                          "THEN\n"
                          "Adjuvant chemotherapy\n"
                          "AND\n"
                          "See BINV 17")
                    user_response = input("(Yes/No): ").strip().lower()
                    if user_response == "yes":
                        print("See BINV 17")
                    elif user_response == "no":
                        print("Rule 54: IF tumor is of histologic type:\n"
                              "- Ductal/NSTu\n"
                              "- Lobular\n"
                              "- Mixed\n"
                              "- Micropapillary\n"
                              "- Metaplasticv\n"
                              "AND\n"
                              "- pN+ (≥1 ipsilateral metastases >2 mm)\n"
                              "THEN\n"
                              "Adjuvant chemotherapya,cc\n"
                              "AND\n"
                              "See BINV 17")
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")

def ask_for_BINV10_rules():
    user_response = input("Do you want to know the BINV10 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV10 rules:")
        print("Rule 50: IF tumor is of histologic type:\n"
              "- Ductal/NSTu\n"
              "- Lobular\n"
              "- Mixed\n"
              "- Micropapillary\n"
              "- Metaplasticv\n"
              "AND\n"
              "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
              "AND\n"
              "- Tumor ≤0.5 cm\n"
              "AND\n"
              "- pN0\n")
              
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("No adjuvant therapyqq. See BINV 17")
        elif user_response == "no":
            print("Rule 51: IF tumor is of histologic type:\n"
                  "- Ductal/NSTu\n"
                  "- Lobular\n"
                  "- Mixed\n"
                  "- Micropapillary\n"
                  "- Metaplasticv\n"
                  "AND\n"
                  "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                  "AND\n"
                  "- Tumor ≤0.5 cm\n"
                  "AND\n"
                  "- pN1mi\n")
                  
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == "yes":
                print("Consider adjuvant chemotherapya,c. See BINV 17")
            elif user_response == "no":
                print("Rule 52: IF tumor is of histologic type:\n"
                      "- Ductal/NSTu\n"
                      "- Lobular\n"
                      "- Mixed\n"
                      "- Micropapillary\n"
                      "- Metaplasticv\n"
                      "AND\n"
                      "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                      "AND\n"
                      "- Tumor 0.6–1.0 cm\n")
                     
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == "yes":
                    print("Consider adjuvant chemotherapya,cc. See BINV 17")
                elif user_response == "no":
                    print("Rule 53: IF tumor is of histologic type:\n"
                          "- Ductal/NSTu\n"
                          "- Lobular\n"
                          "- Mixed\n"
                          "- Micropapillary\n"
                          "- Metaplasticv\n"
                          "AND\n"
                          "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                          "AND\n"
                          "- Tumor >1 cm\n")
                      
                    user_response = input("(Yes/No): ").strip().lower()
                    if user_response == "yes":
                        print("Adjuvant chemotherapy. See BINV 17")
                    elif user_response == "no":
                        print("Rule 54: IF tumor is of histologic type:\n"
                              "- Ductal/NSTu\n"
                              "- Lobular\n"
                              "- Mixed\n"
                              "- Micropapillary\n"
                              "- Metaplasticv\n"
                              "AND\n"
                              "- pN+ (≥1 ipsilateral metastases >2 mm)\n")
                        if user_response == "yes":
                            print("Adjuvant chemotherapya,cc.See BINV 17")
                        elif user_response == "no":
                            print("No BINV17 rules will be provided")
                        else:
                            print("Invalid response. Please answer 'Yes' or 'No'.")       
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")

                
                    
def ask_for_BINV11_rules():
    user_response = input("Do you want to know the BINV11 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Here are the BINV11 rules:")
        print("Rule 55: IF tumor is of histologic type:\n"
              "- Pure tubular\n"
              "- Pure mucinous\n"
              "- Pure cribriform\n"
              "- Encapsulated or solid papillary carcinoma\n"
              "AND\n"
              "- ER-positive and/or PR-positive, HER2-negativey\n"
              "AND\n"
              "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
              "AND\n"
              "- Tumor <1 cm\n")
              
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Consider adjuvant endocrine therapybb for risk reduction. See BINV 17")
        elif user_response == "no":
            print("Rule 56: IF tumor is of histologic type:\n"
                  "- Pure tubular\n"
                  "- Pure mucinous\n"
                  "- Pure cribriform\n"
                  "- Encapsulated or solid papillary carcinoma\n"
                  "AND\n"
                  "- ER-positive and/or PR-positive, HER2-negativey\n"
                  "AND\n"
                  "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                  "AND\n"
                  "- Tumor 1–2.9 cm\n")
               
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == "yes":
                print("Consider adjuvant endocrine therapybb. See BINV 17")
            elif user_response == "no":
                print("Rule 57: IF tumor is of histologic type:\n"
                      "- Pure tubular\n"
                      "- Pure mucinous\n"
                      "- Pure cribriform\n"
                      "- Encapsulated or solid papillary carcinoma\n"
                      "AND\n"
                      "- ER-positive and/or PR-positive, HER2-negativey\n"
                      "AND\n"
                      "- pT1, pT2, or pT3; and pN0 or pN1mi (≤2 mm axillary node metastasis)\n"
                      "AND\n"
                      "- Tumor ≥3 cm\n")
                     
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == "yes":
                    print("Adjuvant endocrine therapy. See BINV 17")
                elif user_response == "no":
                    print("Rule 58: IF tumor is of histologic type:\n"
                          "- Pure tubular\n"
                          "- Pure mucinous\n"
                          "- Pure cribriform\n"
                          "- Encapsulated or solid papillary carcinoma\n"
                          "AND\n"
                          "- ER-positive and/or PR-positive, HER2-negativey\n"
                          "AND\n"
                          "- pN+ (≥1 ipsilateral metastases >2 mm)\n")
                         
                    user_response = input("(Yes/No): ").strip().lower()
                    if user_response == "yes":
                        print("Adjuvant endocrine therapybb,ff ± adjuvant chemotherapya,bb,cc.See BINV 17")
                    elif user_response == "no":
                        print("Rule 59: IF tumor is of histologic type:\n"
                              "- Adenoid cystic and other salivary carcinomas\n"
                              "- Secretory carcinoma\n"
                              "- Rare low-grade forms of metaplastic carcinoma\n"
                              "AND\n"
                              "- ER-negative and PR-negative, HER2-negativey\n")
                        if user_response == "yes":
                            print("Limited available data support local therapy only with consideration for systemic/targeted therapies only in pN+ disease.See BINV 17")
                        elif user_response == "no":
                            print("No more BINV 11 rules to provide")
                        else:
                            print("Invalid response. Please answer 'Yes' or 'No'.")          
                        
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")
                  
def ask_for_BINV12_rule():
    user_response = input("Do you want to know the BINV12 rule? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("Rule 60: IF the patient has:")
        print("- cT2 or higher (c≥T2tt) tumor")
        print("- cN+ (lymph node positive)")
        print("- M0 (no distant metastasis)")
        print("- OR cT1 HER2-positive disease (cT1c, cN0 HER2-positive)")
        print("- OR cT1 TNBC (cT1c, cN0 TNBC)")
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("THEN")
            print("Perform the following assessments:")
            print("- Axillary assessment with exam")
            print("- Consider ultrasound")
            print("- Perform percutaneous biopsy of suspicious nodesss")
            print("- Conduct CBC")
            print("- Conduct comprehensive metabolic panel, including liver function tests and alkaline phosphatase")
            print("Perform additional tests as clinically indicated:")
            print("- Chest diagnostic CT ± contrast")
            print("- Abdominal ± pelvic diagnostic CT with contrast or MRI with contrast")
            print("- Bone scan or sodium fluoride PET/CT (category 2B)")
            print("- FDG PET/CT (useful in certain circumstances)")
            print("Optional: Breast MRIb, with special consideration for mammographically occult tumors, if not previously done")
            print("Refer to BINV 12a")
            ask_for_BINV12a_rule()
        elif user_response == "no":
            print("No further guidance provided.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")

def ask_for_BINV12a_rule():
    user_response = input("Do you want to know the BINV12a rule? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("BINV 12a:")
        print("Rule 1: If For operable breast cancers")
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Then: Refer to Breast and Axillary Evaluation Prior to Preoperative Systemic Therapy (BINV-13)")
            ask_for_BINV13_rule()
        elif user_response == "no":
            print("Rule 2: If inoperable breast cancers")
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == "yes":
                print("Then: Refer to Preoperative Systemic Therapy (BINV-15)")
                ask_for_BINV15_rules()
            elif user_response == 'no':
                print("No more rules to provide")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")      
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")

def ask_for_BINV13_rule():
    user_response = input("Do you want to know the BINV13 rule? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("BINV 13:")
        print("Rule 61: IF prior to preoperative systemic therapy, the following procedures have not been performed:")
        print("- Core biopsy of the breast with placement of image-detectable clips or marker(s) to demarcate the tumor bed")
        print("- Axillary imaging with ultrasound or MRI")
        print("- Biopsy + clip placement of suspicious and/or clinically positive axillary lymph nodes")
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("THEN Perform the following actions:")
            print("- Perform preoperative systemic therapy based on HR (Hormone Receptor) and HER2 (Human Epidermal Growth Factor Receptor 2) status")
            print("AND See Surgical Treatment and Adjuvant Therapy After Preoperative Systemic Therapy (BINV-14)")
            ask_for_BINV14_rules()
        elif user_response == "no":
            print("No further guidance provided.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")
        
        
def ask_for_BINV14_rules():
    user_response = input("Do you want to know the BINV14 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("BINV14 Rules:")
        print("Rule 62: IF BCS (Breast-Conserving Surgery) is possible")
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Perform the following actions:")
            print("- Perform BCS with surgical axillary stagingj (see BINV-D) ± oncoplastic reconstruction")
            print("AND")
            print("- Administer adjuvant systemic therapyrr,xx (see BINV-16)")
            print("- Administer post-lumpectomy adjuvant RTo (Radiotherapy):")
            print("  - For cN+ and ypN0: Adjuvant RT to the whole breast ± boost to the tumor bed;yy and strongly consider comprehensive RNI with inclusion of any portion of the undissected axilla at risk.")
            print("  - For any ypN+: Adjuvant RT to the whole breast ± boost to the tumor bed;yy and comprehensive RNI with inclusion of any portion of the undissected axilla at risk.")
            print("  - For any cN0, ypN0: Adjuvant RT to the whole breast ± boost to tumor bed")
        elif user_response == "no":
            print("Rule 63: IF BCS is not possible")
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == "yes":
                print("Perform the following actions:")
                print("- Perform mastectomy and surgical axillary stagingj (see BINV-D) + reconstruction (optional)")
                print("AND")
                print("- Administer adjuvant systemic therapyrr,xx (see BINV-16)")
                print("- Administer post-mastectomy adjuvant RTo (Radiotherapy):")
                print("  - For cN+ and ypN0: Strongly consider RT to the chest wall and comprehensive RNI with inclusion of any portion of the undissected axilla at risk.")
                print("  - For any ypN+: RT is indicated to the chest wall + comprehensive RNI with inclusion of any portion of the undissected axilla at risk.")
                print("  - Administer adjuvant systemic therapyrr,ww (see BINV-16) without adjuvant RT for any cN0, ypN0 if axilla was assessed by SLNB or axillary node dissection")
            elif user_response == "no":
                print("No further guidance provided.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")
        
        
def ask_for_BINV15_rules():
    user_response = input("Do you want to know the BINV15 rules? (Yes/No): ").strip().lower()
    if user_response == "yes":
        print("BINV15 Rules:")
        print("Rule 64: IF Preoperative systemic therapyqq AND IF Response to preoperative systemic therapyvv and tumor is operable")
        user_response = input("(Yes/No): ").strip().lower()
        if user_response == "yes":
            print("Perform the following actions:")
            print("- Perform Mastectomy and surgical axillary stagingj + reconstruction (optional)q")
            print("- OR Perform BCS with surgical axillary stagingj,zz ± oncoplastic reconstruction")
            print("AND")
            print("- Administer Adjuvant systemic therapyxx (see BINV-16)")
            print("- Administer Adjuvant RTo to the whole breast or chest wall and comprehensive RNI with inclusion of any portion of the undissected axilla at risk.")
        elif user_response == "no":
            print("Rule 65: IF Preoperative systemic therapyqq AND IF No response to preoperative systemic therapyvv and/or tumor remains inoperable")
            user_response = input("(Yes/No): ").strip().lower()
            if user_response == "yes":
                print("Consider additional systemic therapy and/or preoperative radiation")
            elif user_response == "no":
                print("Rule 66: IF Preoperative systemic therapyqq AND IF Response to preoperative systemic therapyvv and tumor is operable")
                user_response = input("(Yes/No): ").strip().lower()
                if user_response == "yes":
                    print("Perform the following actions:")
                    print("- Perform Mastectomy and surgical axillary stagingj + reconstruction (optional)q")
                    print("- OR Perform BCS with surgical axillary stagingj,zz ± oncoplastic reconstruction")
                    print("AND")
                    print("- Administer Adjuvant systemic therapyxx (see BINV-16)")
                    print("- Administer Adjuvant RTo to the whole breast or chest wall and comprehensive RNI with inclusion of any portion of the undissected axilla at risk.")
                elif user_response == "no":
                    print("Rule 67: IF Preoperative systemic therapyqq AND IF No response to preoperative systemic therapyvv and/or tumor remains inoperable")
                    user_response = input("(Yes/No): ").strip().lower()
                    if user_response == "yes":
                        print("Consider additional systemic therapy and/or preoperative radiation")
                    elif user_response == "no":
                        print("No further guidance provided.")
                    else:
                        print("Invalid response. Please answer 'Yes' or 'No'.")
                else:
                    print("Invalid response. Please answer 'Yes' or 'No'.")
            else:
                print("Invalid response. Please answer 'Yes' or 'No'.")
        else:
            print("Invalid response. Please answer 'Yes' or 'No'.")
    else:
        print("Invalid response. Please answer 'Yes' or 'No'.")


            
            
# Call the function to start the diagnosis
perform_diagnosis()
# Out:
# Choose one of the following options:
# 1. DCIS Tis, N0, M0 diagnosed
# 2. Non-metastatic (M0) invasive breast cancer
# 3. Metastatic (M1) invasive breast cancer and Stage IV (M1) or Recurrent disease
# 4. Clinical pathologic diagnosis of inflammatory breast cancer
# Enter the option number: 2
# Due to non Non-metastatic (M0) invasive breast cancer:
# Is cT0, cN+ and M0 from imaging and testing? (Yes/No): no
# Is cT1–T3 and ≥cN0,M0 from imaging and testing? (Yes/No): yes
# See criteria for preoperative systemic therapy (BINV-M)
# Are you considering preoperative systemic therapy? (Yes/No): no
# Locoregional treatment:
# - See BCS Followed by RT (BINV-2) or
# - See Mastectomy Followed by RT (BINV-3)
# Do you want to know the BINV2 rules? (Yes/No): yes
# Here are the BINV2 rules:
# Rule 1: Is it BCS with surgical axillary staging (category 1)i,j,k,l ± oncoplastic reconstruction and if Negative axillary nodes?
#  (Yes/No): yes
# ...
